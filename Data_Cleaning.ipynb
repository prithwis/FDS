# %% [markdown]
# <a href="https://colab.research.google.com/github/prithwis/FDS/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CC-BY-SA](https://licensebuttons.net/l/by-sa/3.0/88x31.png)<br>
# <hr>
#
# ![alt text](https://github.com/Praxis-QR/RDWH/raw/main/images/YantraJaalBanner.png)<br>
#
#
# <hr>
#
# [Prithwis Mukerjee](http://www.linkedin.com/in/prithwis)<br>

# %%
from datetime import datetime
import pytz
print("\033[1m"+'ॐ श्री गणेशाय नमः'+"\033[0m")
print(datetime.now(pytz.timezone('Asia/Calcutta')))
# Out:
# ॐ श्री गणेशाय नमः
# 2026-08-31 11:57:42.283291+05:30

# %% [markdown]
# #Data Cleaning
# [Original Tutorial](https://www.shiksha.com/online-courses/articles/data-cleaning-using-pandas/) <br>
# [Saved File](https://github.com/Praxis-QR/FDS/blob/main/Docs/DataCleaningTutorial.pdf)

# %%
import pandas as pd

# %%
# !wget -q -O data.csv https://github.com/Praxis-QR/FDS/raw/main/data/AB_NYC.csv

# %%
#Importing the dataset by reading the csv file
#df = pd.read_csv('AB_NYC_2019.csv')
df0 = pd.read_csv('data.csv')
df0.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#First look at the data
#
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48903 entries, 0 to 48902
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48903 non-null  int64
#  1   name                            48887 non-null  object
#  2   host_id                         48903 non-null  int64
#  3   host_name                       48882 non-null  object
#  4   neighbourhood_group             48903 non-null  object
#  5   neighbourhood                   48903 non-null  object
#  6   latitude                        48903 non-null  float64
#  7   longitude                       48903 non-null  float64
#  8   room_type                       48903 non-null  object
#  9   price                           48903 non-null  int64
#  10  minimum_nights                  48903 non-null  int64
#  11  number_of_reviews               48903 non-null  int64
# ...

# %%
#Finding duplicated values in a DataFrame
#Difficult to find
df0.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48898    False
# 48899    False
# 48900    False
# 48901    False
# 48902    False
# Length: 48903, dtype: bool

# %%
#Finding duplicated values in a DataFrame
#Check if any are duplicate
df0.duplicated().any()
# Out:
# np.True_

# %%
#Finding duplicated values in a DataFrame
#Check if any are duplicate
df0[df0.duplicated]
# Out:
#            id                                        name   host_id  \
# 4303  2862900           Charming & Bright Studio @ W 50's   3716641
# 4304  2863223             Cozy Room with Private Entrance  14586041
# 4305  2863408         Newly Renovated Modern 1-Bed Studio  13347167
# 4306  2863530           APPARTEMENT 2 CHAMBRES ASTORIA NY  14636480
# 4307  2863589  Entire Private Modern Studio UPW Manhattan   3716641
# 4308  2863696                     Live in a doll factory!   5229579
# 4309  2864637         Ting Ting's Home in Heart of Brklyn  14641776
# 4310  2865117           Huge and beautiful Park Slope Apt   3543836
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# 4303            Ofer           Manhattan   Hell's Kitchen  40.76634
# 4304           Louie            Brooklyn     Williamsburg  40.70665
# 4305  AFI Apartments           Manhattan  Upper East Side  40.77233
# 4306            Ilda              Queens          Astoria  40.77182
# ...

# %%
#df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
#df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=False)
df1 = df0.drop_duplicates(subset=None, keep='first', ignore_index=False)

# %%
#Finding duplicated values in a DataFrame
df1.duplicated().any()
# Out:
# np.False_

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48895 entries, 0 to 48902
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
#Finding missing values in a DataFrame
df1.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48898  False  False    False      False                False          False
# 48899  False  False    False      False                False          False
# 48900  False  False    False      False                False          False
# 48901  False  False    False      False                False          False
# 48902  False  False    False      False                False          False
#
# ...

# %%
#Finding missing values in a DataFrame
df1.isna()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48898  False  False    False      False                False          False
# 48899  False  False    False      False                False          False
# 48900  False  False    False      False                False          False
# 48901  False  False    False      False                False          False
# 48902  False  False    False      False                False          False
#
# ...

# %%
#Finding missing values in a DataFrame
#Which values are missing
#
df1.isna().any()
# Out:
# id                                False
# name                               True
# host_id                           False
# host_name                          True
# neighbourhood_group               False
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# last_review                        True
# reviews_per_month                  True
# calculated_host_listings_count    False
# availability_365                  False
# dtype: bool

# %%
#Finding missing values in a DataFrame
#How many values are missing

df1.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#Replacing N/A values in a DataFrame
#df.fillna({'name':'Not Stated','host_name':'Not Stated','last_review':0}, inplace=True)
#df1.fillna({'name':'Not Stated','host_name':'Not Stated','last_review':'1-1-1900','reviews_per_month':0}, inplace=True)
df2 = df1.fillna({'name':'Not Stated','host_name':'Not Stated','last_review':'1-1-1900','reviews_per_month':0})

# %%
#19-10-2018

# %%
df2.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
#Dropping columns in a DataFrame
df2.drop(['reviews_per_month'], axis = 1, inplace=True)

# %%
df2.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
#Check if all review IDs are unique
#Changing the index of a DataFrame
#df['id'].is_unique    # original dataframe, not unique
df2['id'].is_unique    # current dataframe, unique
# Out:
# True

# %%
#Let’s set the 'id' column as index using set_index:
df2 = df2.set_index('id')
df2.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
df2.iloc[4]
# Out:
# name                              Entire Apt: Spacious Studio/Loft by central park
# host_id                                                                       7192
# host_name                                                                    Laura
# neighbourhood_group                                                      Manhattan
# neighbourhood                                                          East Harlem
# latitude                                                                  40.79851
# longitude                                                                -73.94399
# room_type                                                          Entire home/apt
# price                                                                           80
# minimum_nights                                                                  10
# number_of_reviews                                                                9
# ...

# %%
#Renaming column of a DataFrame
new_col = {'name':'listing_name', 'number_of_reviews':'reviews'}

df2.rename(columns=new_col, inplace=True)
df2.head()
# Out:
#                                           listing_name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
df2['last_review'].dtype.type
# Out:
# numpy.object_

# %%
#Converting data type
df2['last_review'] = pd.to_datetime(df2['last_review'], format='%d-%m-%Y')
df2['last_review'].dtype.type
# Out:
# numpy.datetime64

# %%
#Converting data type to reduce memory
df2['host_id'] = df2['host_id'].astype('int32')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48895 entries, 2539 to 36487245
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   listing_name                    48895 non-null  object
#  1   host_id                         48895 non-null  int32
#  2   host_name                       48895 non-null  object
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  reviews                         48895 non-null  int64
#  11  last_review                     48895 non-null  datetime64[ns]
# ...

# %% [markdown]
# More complex examples<br>
# https://realpython.com/python-data-cleaning-numpy-pandas/

# %% [markdown]
# #ChronoTantra | ChronoYantra | ChronoMantra | ChronoSutra
#  [Finished scrolling? Now try reading a book. ](http://chronos.yantrajaal.com) <br>
#
# [![More Information](https://raw.githubusercontent.com/prithwis/parashar21/refs/heads/main/images/CTYMS-Colab-Footer.png)](https://chronos.yantrajaal.com)
